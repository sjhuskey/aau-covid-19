# %%
import pandas as pd

# %%
data = pd.read_csv('data-7G1ie.csv')

# %%
data
# Out:
#                                                College  \
# 0    [Adelphi University](https://www.adelphi.edu/n...
# 1    [Agnes Scott College](https://www.agnesscott.e...
# 2    [Albany College of Pharmacy and Health Science...
# 3    [Albany Law School](https://www.albanylaw.edu/...
# 4    [Albert Einstein College of Medicine](https://...
# ..                                                 ...
# 768  [Worcester Polytechnic Institute](https://www....
# 769  [Xavier University of Louisiana](https://xula....
# 770  [Yale University](https://www.wfsb.com/news/ya...
# 771  [Yeshiva University](https://www.yu.edu/covid-...
# 772  [York County Community College](https://www.mc...
#
#                                          Unnamed: 1  AAU    Announce date  \
# 0                                Adelphi University  NaN    July 26, 2021
# 1                               Agnes Scott College  NaN      May 7, 2021
# 2    Albany College of Pharmacy and Health Sciences  NaN               --
# ...

# %%
data.columns
# Out:
# Index(['College', 'Unnamed: 1', 'AAU', 'Announce date', 'Type',
#        'State  ^Color denotes 2020 presidential result^',
#        'Employees  ^(Vaccination required)^',
#        'All students  ^(Vaccination required)^',
#        'Only residential students  ^(Vaccination required)^', 'state_pol'],
#       dtype='object')

# %%
AAU = data[['College','AAU','Type','Employees  ^(Vaccination required)^','All students  ^(Vaccination required)^','state_pol']]

# %%
AAU = AAU[AAU['AAU'] == 'Y']

# %%
AAU
# Out:
#                                                College AAU     Type  \
# 40   [Boston University](https://www.bu.edu/preside...   Y  Private
# 43   [Brandeis University](https://www.brandeis.edu...   Y  Private
# 48   [Brown University](https://www.providencejourn...   Y  Private
# 58   [California Institute of Technology](https://s...   Y  Private
# 82   [Carnegie Mellon University](https://www.cmu.e...   Y  Private
# 84   [Case Western Reserve University](https://case...   Y  Private
# 148  [Columbia University](https://covid19.columbia...   Y  Private
# 154  [Cornell University](https://news.cornell.edu/...   Y  Private
# 178  [Dartmouth College](https://www.thedartmouth.c...   Y  Private
# 192  [Duke University](https://today.duke.edu/2021/...   Y  Private
# 207  [Emory University](https://twitter.com/gregfen...   Y  Private
# 255  [Harvard University](https://www.harvard.edu/p...   Y  Private
# 278  [Indiana University at Bloomington](https://ww...   Y   Public
# ...

# %%
len(AAU)
# Out:
# 46

# %%
AAU.to_csv('aau-with-policy.csv')
